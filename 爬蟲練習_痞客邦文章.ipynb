# %% [markdown]
# # 痞客邦文章爬文

# %%
import requests
res = requests.get("https://butterfly927.pixnet.net/blog/post/46339070")
res.encoding = "UTF-8" #解決亂碼問題
print(res.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="zh-TW" itemscope itemtype="http://schema.org/Blog">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <meta name="referrer" content="always">
# <meta property="og:site_name" content="蝶樂|在修行的天空中飛舞">
# <meta property="og:locale" content="zh_TW">
# <meta property="og:url" content="http://butterfly927.pixnet.net/blog/post/46339070">
# <meta property="og:type" content="article" />
# <meta property="og:title" content="勵志文章分享│放下八件事 @ 蝶樂|在修行的天空中飛舞 :: 痞客邦 ::" />
# <meta property="og:description" content="1、放下壓力，累與不累，取決於自己的心態 心靈的房間，不打掃就會落滿灰塵。蒙塵的心，會變得灰色和迷茫。我們每天都要經歷很多事情，開心的，不開心的，都在心裡安家落戶。心裡的事情一多，就會變得雜亂無序，然" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <meta name="twitter:card" content="summary">
# <meta name="description" content="1、放下壓力，累與不累，取決於自己的心態 心靈的房間，不打掃就會落滿灰塵。蒙塵的心，會變得灰色和迷茫。我們每天都要經歷很多事情，開心的，不開心的，都在心裡安家落戶。心裡的事情一多，就會變得雜亂無序，然">
# <meta name="twitter:description" content="1、放下壓力，累與不累，取決於自己的心態 心靈的房間，不打掃就會落滿灰塵。蒙塵的心，會變得灰色和迷茫。我們每天都要經歷很多事情，開心的，不開心的，都在心裡安家落戶。心裡的事情一多，就會變得雜亂無序，然">
# <meta name="twitter:site" content="@pixnet">
# <meta name="author" content="蝶樂 (butterfly927)">
# <meta name="author-avatar-20" content="https://s5.pimg.tw/avatar/butterfly927/0/0/zoomcrop/20x20.png?v=1279123007">
# <meta name="static-version" content="34e16fe28a09c688e00acd6028beefd8">
# <meta name="generator" content="PChoc">
# <meta name="google-site-verification" content="rOuWVTCmR4icUG6dEtcW77KJd2UfTw_v4I7t39PKUEs">
# <meta name="msvalidate.01" content="D7E1931751BCCE6F41DB2D1705975936">
# <meta name="keywords" content="禪,妙天師父,妙天,妙天禪師,修行,禪修,文章分享,散文筆記,網路好文分享,勵志文章分享│放下八件事">
# <link rel="canonical" href="https://butterfly927.pixnet.net/blog/post/46339070-%e5%8b%b5%e5%bf%97%e6%96%87%e7%ab%a0%e5%88%86%e4%ba%ab%e2%94%82%e6%94%be%e4%b8%8b%e5%85%ab%e4%bb%b6%e4%ba%8b">
# <meta name="twitter:url" content="https://butterfly927.pixnet.net/blog/post/46339070">
# <meta name="cover_image" content="">
# <meta name="twitter:image" content="">
# <link rel="prev" href="https://butterfly927.pixnet.net/blog/post/46255190">
# <link rel="next" href="https://butterfly927.pixnet.net/blog/post/46499358">
# <link rel="alternate" type="application/json+oembed" href="https://api.pixnet.cc/oembed?url=https%3A%2F%2Fbutterfly927.pixnet.net%2Fblog%2Fpost%2F46339070&amp;format=json" title="PIXNET oEmbed Profile">
# <link rel="alternate" type="text/xml+oembed" href="https://api.pixnet.cc/oembed?url=https%3A%2F%2Fbutterfly927.pixnet.net%2Fblog%2Fpost%2F46339070&amp;format=xml" title="PIXNET oEmbed Profile">
# <link rel="search" type="application/opensearchdescription+xml" href="https://butterfly927.pixnet.net/blog/opensearch" title="蝶樂|在修行的天空中飛舞">
# <title>勵志文章分享│放下八件事 @ 蝶樂|在修行的天空中飛舞 :: 痞客邦 ::</title>
# <meta name="twitter:title" content="勵志文章分享│放下八件事 @ 蝶樂|在修行的天空中飛舞 :: 痞客邦 ::">
# <base href="https://butterfly927.pixnet.net/blog/post/46339070">
#
# <style type="text/css">
# #links-row-1 .m31361B-mib-ad-sidebar-v2-m31361b {display: block !important; min-width: 160px !important; min-height: 270px !important; margin-top: 0; z-index:100;}
# .m31361B-mib-ad-sidebar-v2-m31361b * { padding: 0 ; margin: 0 ; border: 0; vertical-align: baseline; display: block; line-height: 1; }
# .m31361B-mib-ad-sidebar-v2-m31361b .box-text { overflow:hidden; padding:0; margin:0; }
# .m31361B-mib-ad-sidebar-v2-m31361b .box-text a {height: auto;}
# .m31361B-mib-border-m31361b { padding: 0; min-width: 180px; min-height: 280px; margin: 12px auto; overflow: hidden; text-align:center; }
# .m31361B-mib-border-m31361b img, .m31361B-mib-border-m31361b div { margin:0 auto; display:inline-block; min-width:160px; }
# .m31361B-mib-border-m31361b_1080 {padding: 0; width: 180px; height: 280px; margin: 12px auto; overflow: hidden;}
# .m31361B-mib-border-m31361b div {position: relative;}
# </style>
# <link rel="stylesheet" href="//front.pixfs.net/css/mib/video.css?v=34e16fe28a09c688e00acd6028beefd8" type="text/css">
# <link rel="stylesheet" href="//front.pixfs.net/css/lang-css.css?v=34e16fe28a09c688e00acd6028beefd8" type="text/css">
# <link rel="stylesheet" href="//front.pixfs.net/css/iframe-popup.css?v=34e16fe28a09c688e00acd6028beefd8" type="text/css">
# <link rel="stylesheet" href="//s.pixfs.net/blog/plugins/plugins.min.css?v=34e16fe28a09c688e00acd6028beefd8" type="text/css">
# <link rel="stylesheet" href="//front.pixfs.net/comment/openid-comment.css?v=34e16fe28a09c688e00acd6028beefd8" type="text/css">
# <link rel="stylesheet" href="//front.pixfs.net/css/guestbook/style.min.css?v=34e16fe28a09c688e00acd6028beefd8" />
# <link rel="stylesheet" href="//front.pixfs.net/css/desktop/styles/main.min.css?v=34e16fe28a09c688e00acd6028beefd8">
# <link rel="stylesheet" href="https://css.pixnet.in/blog/butterfly927/normal.css?v=1507874384" type="text/css">
# <link rel="stylesheet" href="//front.pixfs.net/css/falcon-ad.css?v=34e16fe28a09c688e00acd6028beefd8">
# <link rel="stylesheet" href="//front.pixfs.net/css/iframe-popup.css?v=34e16fe28a09c688e00acd6028beefd8" type="text/css">
# <link rel="stylesheet" href="//front.pixfs.net/css/author-info.css?v=34e16fe28a09c688e00acd6028beefd8" type="text/css">
# <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="http://feed.pixnet.net/blog/posts/rss/butterfly927">
# <link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="http://feed.pixnet.net/blog/posts/atom/butterfly927">
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="http://api.pixnet.cc/blog/xmlrpc?rsd=butterfly927">
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="http://api.pixnet.cc/static/blog/wlwmanifest.xml">
#
#
#
# <script type="text/javascript" src="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js" crossorigin="anonymous"></script>
# <script type="text/javascript" src="//libs.pixfs.net/jquery.onappear/jquery.onAppear.min.js"></script>
# <script src="//libs.pixfs.net/json2/json2.min.js" type="text/javascript"></script>
# <script src="//libs.pixfs.net/spin.js/spin.min.js" type="text/javascript"></script>
# <script>
# var pix = pix || {};
# pix.panelsite = 'classic-panel.pixnet.cc';
# pix.apisite = 'api.pixnet.cc';
# pix.login_name = 'f7bb3eed50b5df42017f08d33c7bb0a4';
# pix.visitor = "YzQxNTdjZjZiZTgxNTIwOGFiZjEzNWQ1ZWFkYjA3OGM=";
# pix.openid = "YzQxNTdjZjZiZTgxNTIwOGFiZjEzNWQ1ZWFkYjA3OGM=";
# pix.member_uniqid = "YzQxNTdjZjZiZTgxNTIwOGFiZjEzNWQ1ZWFkYjA3OGM=";
# pix.owner = 'butterfly927';
# pix.is_owner = false;
# pix.server_name = 'butterfly927.pixnet.net';
# pix.sToken = "13db5efe44d8599b89508756da3312e1";
# pix.pixfssite = 's.pixfs.net';
# pix.falconsite = 'falcon.pixnet.net';
# pix.checklogin_version = 2;
# pix.checklogin_callback = '/api/blog/checklogin'
# pix.secureProtocol = 'https://';
# pix.domain_append = '';
# // timezone: null;
# </script>
# <script  src="https://member.pixnet.cc/api/checklogin.php?js=1&amp;unique=531168849&amp;timestamp=1584162828&amp;type=2"></script>
# <script  src="https://s.pixfs.net/js/pixnet/checklogin.min.js?v=34e16fe28a09c688e00acd6028beefd8"></script>
# <script type="text/javascript">
# <!--
# jQuery.noConflict();
# var pix = pix || {};
# pix.ab_testing_seed = 1940476875;
# dataLayer = window.dataLayer || [];
# //-->
# </script>
# <script src="//s.pixfs.net/js/lang/zh_TW.js?v=34e16fe28a09c688e00acd6028beefd8" type="text/javascript"></script>
# <script src="//s.pixfs.net/js/pix.min.js?v=34e16fe28a09c688e00acd6028beefd8" type="text/javascript" crossorigin="anonymous"></script>
# <script src="//s.pixfs.net/js/pix-addon.min.js?v=34e16fe28a09c688e00acd6028beefd8" crossorigin="anonymous"></script>
# <script src="//front.pixfs.net/js/all.min.js?v=34e16fe28a09c688e00acd6028beefd8" type="text/javascript" crossorigin="anonymous"></script>
# <script src="//front.pixfs.net/js/blog.min.js?v=34e16fe28a09c688e00acd6028beefd8" type="text/javascript" crossorigin="anonymous"></script>
# <script src="//front.pixfs.net/js/search_selection.min.js?v=34e16fe28a09c688e00acd6028beefd8" type="text/javascript"></script>
# <script defer src="//front.pixfs.net/js/member-subscribe.min.js?v=34e16fe28a09c688e00acd6028beefd8" crossorigin="anonymous"></script>
#
# <meta itemprop="name" content="勵志文章分享│放下八件事 @ 蝶樂|在修行的天空中飛舞 :: 痞客邦 ::">
# <meta itemprop="description" content="1、放下壓力，累與不累，取決於自己的心態 心靈的房間，不打掃就會落滿灰塵。蒙塵的心，會變得灰色和迷茫。我們每天都要經歷很多事情，開心的，不開心的，都在心裡安家落戶。心裡的事情一多，就會變得雜亂無序，然">
#
# <script type="text/javascript">
# <!--
# var pix = pix || {};
# pix.js_error_type = pix.js_error_type || 'frontblog';
# //-->
# </script>
# <script async type="text/javascript" src="//s.pixfs.net/js/pixlogger.min.js?v=34e16fe28a09c688e00acd6028beefd8"></script>
# <script type="text/javascript">
#
# <!--
# (function(){
#     if (window.size().height > 10 && window.size().width > 10) {
#         var i = new Image(1,1);
#         i.src = 'https://counter.pixplug.in/count.php?timestamp=1584162828&random=2428849836&check=610477408&data[blog]=%7B%22blogid%22%3A%222481435%22%7D&data[blogarticle]=%7B%22blogid%22%3A%222481435%22%2C%22articleid%22%3A%2246339070%22%7D&height=' + window.size().height + '&width=' + window.size().width + '&referer=' + encodeURI(document.referrer);
#         i.onload = function() { return; }
#     }
# })();
# //-->
# </script>
# <!-- Head Modified: 1584162828 -->
# <!-- async script -->
# <script type="text/javascript">
# <!--
# document.addEventListener('DOMContentLoaded', function () {
#     setTimeout(() => {
#         jQuery.ajaxSetup({ cache: true });
#         jQuery.getScript("https://js.pixplug.in/addon/11/production.js?v=1580974906", function(data, textStatus) { jQuery.ajaxSetup({cache: true});jQuery.pixAddonRelatedArticle({"blog_relatedarticleshow":"post","blog_relatedarticle":"site","blog_relatedtemplate":"list","addon_username":"butterfly927","addon_expired_at":0,"addon_ismobile":false,"addon_isvip":false,"addon_is_allow_setting":false,"ab_testing_seed":1940476875});jQuery.ajaxSetup({cache: false}); });
#         jQuery.ajaxSetup({ cache: false });
#     }, pix.lazyLoadDataDelayTime);
# });
# //-->
# </script>
#
# <!-- load sync script -->
#
# <!-- execute sync addon -->
# <script type="text/javascript"></script>
# <script type="text/javascript">
# <!--
# var pix = pix || {};
# pix.visitor_url = "https://butterfly927.pixnet.net/blog";
# pix.visitor_timestamp = "1584162828";
# pix.visitor_nonce = "1584807079";
# pix.visitor_public = "LumrRMVHhADdttHSeUhMM8S3";
# pix.visitor_sig = "31ea5cf1e76c18a24bd560e38294372a";
# pix.user_name = null;
# pix.avatar_version = 0;
# (function() {
#     var js = document.createElement('script');
#     js.src = "\/\/s.pixfs.net\/visitor.pixplug.in\/checklogin.min.js?v=34e16fe28a09c688e00acd6028beefd8";
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(js, s);
# })();
# //-->
# </script>
# <script src="https://s.pixfs.net/polyfill/intersection-observer.js"></script>
#     <script type="text/javascript" src="//front.pixfs.net/js/checkloop.min.js?v=34e16fe28a09c688e00acd6028beefd8"></script>
# <meta http-equiv="imagetoolbar" content="no">
# <script type="text/javascript" src="//libs.pixfs.net/swfobject/1.5/swfobject.js"></script>
# <link href="//libs.pixfs.net/videojs/5.13.2/video-js.min.css" rel="stylesheet">
# <script src="//libs.pixfs.net/videojs/5.13.2/video.min.js" crossorigin="anonymous"></script>
# <meta property="falcon:blogcategory" content="6"><meta property="falcon:articlecategory" content="14"><script async src="//falcon-asset.pixfs.net/js/adsbyfalcon.min.js?v=34e16fe28a09c688e00acd6028beefd8"></script><script src="//front.pixfs.net/js/mib_falcon--bundle.min.js?v=34e16fe28a09c688e00acd6028beefd8" crossorigin="anonymous"></script>
# </head>
#
# <body id="article-main"
#   data-showing-advertisement="yep"
#   data-adsense-state=""
#   data-adsense-classification=""
#   data-blog-site-category-id="6"
#   data-mobile-mode="none"
#   data-ab-testing-seed="1940476875"
#   data-author-member-uniqid="59392571735249c194"
#   data-article-id="46339070"
#   data-comments-count="0"
#   data-shareds-count="10"
#   data-comment-close=""
#   data-comment-page="1"
#   class="category_537672 article_46339070"
#     onDragStart="return false" oncontextmenu="return false" onselectstart="return false"
#     style="-moz-user-select: none;"
#     data-uniqid=""
# >
#
# <script type="text/javascript">
# _atrk_opts = { atrk_acct:"H00Mh1aIE700wg", domain:"pixnet.net",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
# </script>
# <noscript><img src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=H00Mh1aIE700wg" style="display:none" height="1" width="1" alt="" /></noscript>
#
# <div class="header-prompt" id="header-prompt"></div>
# <div class="main-container">
#   <header class="navbar">
#     <div class="navbar-container"></div>
# <script>
#     var projectName = "blog";
#     var deviceType = "desktop";
# </script>
# <script src="//front.pixfs.net/js/pixnavbar-ui-module--bundle.min.js?v=34e16fe28a09c688e00acd6028beefd8" defer></script>
#   </header>
#     <ins class="adsbyfalcon" data-ad-client="1" data-ad-slot="3033" data-embed="false" style="display:inline-block;"></ins>  <div id="body-div">
#   <a name="top"></a>
#   <div id="container">
#     <div id="container2">
#       <div id="container3">
#           <div id="header">
#             <div id="banner">
#         <h1><a href="https://butterfly927.pixnet.net/blog">蝶樂|在修行的天空中飛舞</a></h1>
#               <p class="skiplink"><a href="#article-area" title="skip the page header to the main content">跳到主文</a></p>
#               <h2>帶著一只名為「真善美」的行李，跟隨著妙天師父的步伐，我在回家的路上。
# <link rel="canonical" />
# <script type="text/javascript" src="http://apis.google.com/js/plusone.js">
#   {lang: 'zh-TW'}
# </script></h2>
#           <p id="blog-category">部落格全站分類：<a href="//www.pixnet.net/blog/bloggers/category/6" target="_blank">心情日記</a></p>
#             </div>
#             <ul id="navigation">
#               <li id="link-album"><a href="https://butterfly927.pixnet.net/album" title="go to gallery page of this user">相簿</a></li>
#               <li id="link-blog"><a href="https://butterfly927.pixnet.net/blog" title="go to index page of this blog">部落格</a></li>
#               <li id="link-guestbook">
#                                 <a id="guestbook" data-msg="" data-action="guestbook" href="#side_gb" title="go to guestbook page of this user">留言</a>
#                             </li>
#               <li id="link-profile"><a href="http://www.pixnet.net/pcard/butterfly927?utm_source=PIXNET&utm_medium=blog_text&utm_term=&utm_content=2481435" title="go to profile page of this user">名片</a></li>
#             </ul>
#           </div><!-- #header//-->
#           <div id="main">
#             <div id="content">
#                 <div id="article-area">
#     <div id="article-box">
#             <div class="article" itemscope itemtype="http://schema.org/Article">
#         <meta itemprop="image" content="//s.pixfs.net/mobile/images/blog/article-image.png">
#         <span itemprop="publisher" itemtype="http://schema.org/Organization" itemscope>
#             <meta itemprop="name" content="痞客邦">
#             <span itemprop="logo" itemtype="https://schema.org/ImageObject" itemscope>
#                 <meta itemprop="url" content="https://s.pixfs.net/mainpage2/index/images/footer_logo.png">
#             </span>
#         </span>
#         <ul class="article-head">
#         <li class="publish" itemprop="datePublished" content="2012-08-06T14:19:24.000000+0800"><span class="month">Aug </span><span class="date">06 </span><span class="day">Mon </span><span class="year">2012 </span><span class="time">14:19</span></li>
# <p style="margin-left: 5; margin-right: 5; margin-top: 5; margin-bottom: 0;">　大家在這裡留言，文章分享及留言內容都會自動轉貼到自己的塗鴉牆上，</p>
# <p style="margin-left: 5; margin-right: 5; margin-top: 5; margin-bottom: 0;">　請多多運用喔，讓蝶知道是誰給了我溫暖的鼓勵^_^，感恩呢！</p>
# </div>            </div>
#
# <div class="poi-section">
#     <div class="poi-view">
#         <div class="poi-container">
#                     </div>
#     </div>
#     <a class="poi-prev poi-btn hide">
#         <img src="//front.pixfs.net/images/blog/post/desktop/poi_btn_arrow_back.svg?v=34e16fe28a09c688e00acd6028beefd8">
#     </a>
#     <a class="poi-next poi-btn hide">
#         <img src="//front.pixfs.net/images/blog/post/desktop/poi_btn_arrow_next.svg?v=34e16fe28a09c688e00acd6028beefd8">
#     </a>
#     <ul class="poi-dot"></ul>
# </div>
# <script>
#     var deviceType = "desktop";
#     var poiHashIds = [];
# </script>
# <script src="//front.pixfs.net/js/pixpoi-ui-module--bundle.min.js?v=34e16fe28a09c688e00acd6028beefd8" defer></script>
#
# <div class="tag-container-parent">
#     <div class="tag-container article-keyword" id="article-footer-tags" data-version="a">
#                 <div class="tag__header">
#             <h4 class="tag__header-title">文章標籤</h4>
#         </div>
#         <div class="tag__main">
#                         <a
#                 class="tag"
#                 href="https://www.pixnet.net/tags/%E6%96%87%E7%AB%A0%E5%88%86%E4%BA%AB?utm_source=PIXNET&utm_medium=Blog_article_tag_rule0106"
#                 target="_blank"
#                 data-tag="文章分享"
#             >
#                 <span>文章分享</span>
#             </a>
#                         <a
#                 class="tag"
#                 href="https://www.pixnet.net/tags/%E5%A5%BD%E6%96%87%E7%AB%A0?utm_source=PIXNET&utm_medium=Blog_article_tag_rule0106"
#                 target="_blank"
#                 data-tag="好文章"
#             >
#                 <span>好文章</span>
#             </a>
#                         <a
#                 class="tag"
#                 href="https://www.pixnet.net/tags/%E5%A5%BD%E6%9C%8B%E5%8F%8B?utm_source=PIXNET&utm_medium=Blog_article_tag_rule0106"
#                 target="_blank"
#                 data-tag="好朋友"
#             >
#                 <span>好朋友</span>
#             </a>
#                         <a
#                 class="tag"
#                 href="https://www.pixnet.net/tags/%E7%B6%B2%E8%B7%AF%E6%96%87%E7%AB%A0?utm_source=PIXNET&utm_medium=Blog_article_tag_rule0106"
#                 target="_blank"
#                 data-tag="網路文章"
#             >
#                 <span>網路文章</span>
#             </a>
#                         <a
#                 class="tag"
#                 href="https://www.pixnet.net/tags/%E6%94%BE%E4%B8%8B?utm_source=PIXNET&utm_medium=Blog_article_tag_rule0106"
#                 target="_blank"
#                 data-tag="放下"
#             >
#                 <span>放下</span>
#             </a>
#                         <a
#                 class="tag"
#                 href="https://www.pixnet.net/tags/%E7%97%9B%E8%8B%A6?utm_source=PIXNET&utm_medium=Blog_article_tag_rule0106"
#                 target="_blank"
#                 data-tag="痛苦"
#             >
#                 <span>痛苦</span>
#             </a>
#                         <a
#                 class="tag"
#                 href="https://www.pixnet.net/tags/%E5%B8%83%E8%A2%8B?utm_source=PIXNET&utm_medium=Blog_article_tag_rule0106"
#                 target="_blank"
#                 data-tag="布袋"
#             >
#                 <span>布袋</span>
#             </a>
#                         <a
#                 class="tag"
#                 href="https://www.pixnet.net/tags/%E7%A6%AA%E4%BF%AE?utm_source=PIXNET&utm_medium=Blog_article_tag_rule0106"
#                 target="_blank"
#                 data-tag="禪修"
#             >
#                 <span>禪修</span>
#             </a>
#                         <a
#                 class="tag"
#                 href="https://www.pixnet.net/tags/%E4%BA%BA%E7%94%9F?utm_source=PIXNET&utm_medium=Blog_article_tag_rule0106"
#                 target="_blank"
#                 data-tag="人生"
#             >
#                 <span>人生</span>
#             </a>
#                         <a
#                 class="tag"
#                 href="https://www.pixnet.net/tags/%E8%87%AA%E5%8D%91?utm_source=PIXNET&utm_medium=Blog_article_tag_rule0106"
#                 target="_blank"
#                 data-tag="自卑"
#             >
#                 <span>自卑</span>
#             </a>
#                         <a
#                 class="tag"
#                 href="https://www.pixnet.net/tags/%E8%87%AA%E5%9C%A8?utm_source=PIXNET&utm_medium=Blog_article_tag_rule0106"
#                 target="_blank"
#                 data-tag="自在"
#             >
#                 <span>自在</span>
#             </a>
#                         <a
#                 class="tag"
#                 href="https://www.pixnet.net/tags/%E5%A6%99%E5%A4%A9?utm_source=PIXNET&utm_medium=Blog_article_tag_rule0106"
#                 target="_blank"
#                 data-tag="妙天"
#             >
#                 <span>妙天</span>
#             </a>
#                     </div>
#             </div>
#     <div class="tag-container global-keyword">
#         <div class="tag__header">
#             <h4 class="tag__header-title">全站熱搜</h4>
#         </div>
#         <div class="tag__main">
#         </div>
#     </div>
# </div>
# <script>
#     pix.hotKeywordSvgPath = "https://front.pixfs.net/images/blog/post/mobile/hot_keywords_icon.svg?v=34e16fe28a09c688e00acd6028beefd8";
# </script>
# <script defer src="https://front.pixfs.net/js/hot-keywords.min.js?v=34e16fe28a09c688e00acd6028beefd8"></script>
#
# <div class="author-profile" itemscope itemprop="author" itemtype="http://schema.org/Person">
#     <div class="author-profile__header">創作者介紹</div>
#
#     <div class="author-profile__main" id="mixpanel-author-box">
#         <a href="http://www.pixnet.net/pcard/butterfly927?utm_source=PIXNET&utm_medium=post_card&utm_term=&utm_content=46339070">
#             <img class="author-profile__avatar" src="https://s5.pimg.tw/avatar/butterfly927/0/0/resize/80x0.png?v=1279123007" alt="創作者 蝶樂 的頭像">
#         </a>
#         <div class="author-profile__content">
#             <a
#                 class="author-profile__name"
#                 href="http://www.pixnet.net/pcard/butterfly927?utm_source=PIXNET&utm_medium=post_card&utm_term=&utm_content=46339070"
#             >蝶樂</a>
#             <p class="author-profile__info" itemprop="name">蝶樂|在修行的天空中飛舞</p>
#             <div class="social-links">
#                                                                                                                                                                                                                 </div>
#         </div>
#                     <div class="author-profile__subscribe hoverable">
#
#         <a class="subscribe-btn" href="https://classic-panel.pixnet.cc/login/openid?done=http%3A%2F%2Fbutterfly927.pixnet.net%2Fblog%2Fpost%2F46339070%3Futm_source%3DPIXNET%26utm_medium%3DBlog_follow&openid=https%3A%2F%2Fmember.pixnet.cc%2Flogin&easy_login=1" data-follow-state="關注"></a>
#             </div>
#             </div>
# </div>
#
# <script>
# (function() {
#     if (typeof ga === 'undefined') {
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#     }
#
#     ga('create', 'UA-408650-33', 'auto', {'name': 'subScribeTracker'});
#     var authorAvatar = document.querySelector('.author-profile .author-profile__avatar');
#     var authorName = document.querySelector('.author-profile .author-profile__name');
#     var authorSocialLinks = document.querySelectorAll('.author-profile .author-profile__content .social-link');
#
#     authorAvatar.addEventListener('click', function () { recordEvent('author image'); });
#     authorName.addEventListener('click', function () { recordEvent('author name'); });
#     Array.prototype.forEach.call(authorSocialLinks, function (link) {
#         link.addEventListener('click', function () {
#             var label = link.getAttribute('data-social-type');
#             recordEvent(label);
#         });
#     });
#
#     function recordEvent (label) {
#         var _piq = window._piq || [];
#         _piq.push(['trackEvent', 'author-Intro', 'click-author-Intro', label]);
#         ga('subScribeTracker.send', 'event', 'author-Intro', 'click-author-Intro', label);
#     };
# })();
# </script>
#         </div> <!-- .article-content //-->
#
#         <p class="author">
#             蝶樂 發表在 <a href="https://www.pixnet.net/">痞客邦</a>                    <a href="https://butterfly927.pixnet.net/blog/post/46339070#comments">留言</a>(0) <span class="author-views">人氣(<span id="BlogArticleCount-46339070"></span>)</span>
#                     </p> <!-- .author //-->
#         <div class="forward">
#             <a href="javascript:;" onclick="pix.sendForwardTo('%E6%82%A8%E7%9A%84%E5%A5%BD%E6%9C%8B%E5%8F%8B%E9%82%80%E8%AB%8B%E6%82%A8%E8%A7%80%E7%9C%8B%20butterfly927%20%E7%9A%84%E7%97%9E%E5%AE%A2%E9%82%A6%20PIXNET%20%E9%83%A8%E8%90%BD%E6%A0%BC%E6%96%87%E7%AB%A0-%E5%8B%B5%E5%BF%97%E6%96%87%E7%AB%A0%E5%88%86%E4%BA%AB%E2%94%82%E6%94%BE%E4%B8%8B%E5%85%AB%E4
#         ad1032.append("<ins class=\"adsbyfalcon\" data-ad-client=\"1\" data-ad-slot=\"1032\" data-embed=\"false\" style=\"display:inline-block;\"><\/ins>");
#     } else if (w >= 575 && w <= 599) {
#         ad1032.append("<ins class=\"adsbyfalcon\" data-ad-client=\"1\" data-ad-slot=\"1603\" data-embed=\"false\" style=\"display:inline-block;\"><\/ins>");
#     }
# })(jQuery);
# </script>
# </div>
#         </div> <!-- .article-body //-->
#         <div class="article-footer">
#         <ul class="refer">
#             <li>全站分類：<a href="//www.pixnet.net/blog/articles/category/14">散文筆記</a></li>            <li>個人分類：<a href="https://butterfly927.pixnet.net/blog/category/537672">網路好文分享</a></li>            <li>此分類上一篇： <a class="quick-nav--cat-pre" href="https://butterfly927.pixnet.net/blog/post/45992343">勵志文章分享│好朋友</a></li>
# <li>此分類下一篇： <a class="quick-nav--cat-next" href="https://butterfly927.pixnet.net/blog/post/46596382">禪修心路│類風濕關節炎與身心靈重生</a></li>
#             <li>上一篇： <a class="quick-nav--pre" rel="prev" href="https://butterfly927.pixnet.net/blog/post/46255190" data-public-at="1343705420" data-thumb="https://s8.pimg.tw/album/butterfly927/element/179354048_1343705289-563910394/zoomcrop/90x90.jpg">生活智慧禪│婚姻經營</a></li>
# <li>下一篇： <a class="quick-nav--next" rel="next" href="https://butterfly927.pixnet.net/blog/post/46499358" data-public-at="1344919208" data-thumb="//s.pixfs.net/mobile/images/blog/article-image.png">從悟覺妙天禪師開示看天下│你正在享受福報嗎？</a></li>
#         </ul>
#                         <div class="back-to-top"><a href="#top" title="back to the top of the page">▲top</a></div>
#         </div> <!-- .article-footer //-->
#         </div>
#
# <script>
# // track 上下篇點擊
# (function ($) {
#     'use strict';
#
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-408650-10', 'auto', {'name': 'quickNavTracker'});
#     ga('quickNavTracker.set', 'page', '/blog/');
#
#     var referBlock = $('.refer'),
#         quickNav = {
#             catPre: {
#                 selector: '.quick-nav--cat-pre',
#                 name: '此分類上一篇',
#             },
#             catNext: {
#                 selector: '.quick-nav--cat-next',
#                 name: '此分類下一篇',
#             },
#             pre: {
#                 selector: '.quick-nav--pre',
#                 name: '上一篇',
#             },
#             next: {
#                 selector: '.quick-nav--next',
#                 name: '下一篇',
#             }
#         },
#
#         trackEvent = function (action, label) {
#             ga('quickNavTracker.send', 'event', 'previous-next-page', action, label, { nonInteraction: ('imps' === action) });
#         },
#
#         bindClick = function (selector, label) {
#             referBlock.on('click', selector, function () {
#                 trackEvent('click', label);
#             });
#         };
#
#     for (var key in quickNav) {
#         var obj = quickNav[key];
#         if (referBlock.find(obj.selector).length) {
#             /* 不再記錄曝光 */
#
#             // 點擊時紀錄
#             bindClick(obj.selector, obj.name);
#         }
#     }
#
#         var articleInner = document.querySelector('.article-content-inner'),
#         isSourceFB = getUrlParameter('utm_source') === 'facebook',
#         isSourceFBAD = getUrlParameter('utm_source').indexOf('facebook_ad_') > -1,
#         isSourceGoogleAD = getUrlParameter('utm_source').indexOf('google_ad_') > -1,
#         isSourceRP = getUrlParameter('utm_source').indexOf('RP_') > -1;
#
#     if ((isSourceFB || isSourceFBAD || isSourceGoogleAD || isSourceRP) && articleInner) {
#         var tkExtraParameters = {
#                 'facebook_ad_02': 'retargeting_01',
#                 'facebook_ad_03': 'retargeting_02',
#                 'google_ad_02': 'potential_01',
#                 'google_ad_03': 'potential_02'
#             },
#             testLinks = {
#                 'https://pse.is/JYM9N': '201900120',
#                 'https://pse.is/KUPSW': '201900031',
#                 'https://pse.is/JZH8A': '201900033',
#                 'https://pse.is/KA6L2': '201900024',
#                 'https://pse.is/JVKPG': '201900059',
#                 'https://pse.is/KQZAY': '201900060',
#                 'https://pse.is/MKGUR': '201900189'
#             };
#
#         var urlQuery = '/?adid=71253&af_wid=71&label3=__#CLICK_URL#__&label2=:cdate:__#CLICK_DATE#__::ck:__#COOKIE#__::clk:__#CLICK_ID#__::source:';
#         var mappingLinks = {
#             'https://www.klook.com/zh-TW/activity/2214-hobbiton-movie-set-tour-rotorua?aid=1217': 'https://affiliate.klook.com/jump/zh-TW/activity/2214',
#             'https://goo.gl/fwL97i': 'https://affiliate.klook.com/jump/zh-TW/activity/4498',
#             'https://goo.gl/iTLnU3': 'https://affiliate.klook.com/jump/zh-TW/activity/3588',
#             'https://reurl.cc/V993A': 'https://affiliate.klook.com/jump/zh-TW/activity/9870',
#             'https://goo.gl/Q4drxD': ' https://affiliate.klook.com/jump/zh-TW/activity/3703',
#             'https://goo.gl/5gqVKA': 'https://affiliate.klook.com/jump/zh-TW/activity/3680',
#             'https://goo.gl/KEWTqT': 'https://affiliate.klook.com/jump/zh-TW/activity/3684',
#             'https://goo.gl/UPNRS8': 'https://affiliate.klook.com/jump/zh-TW/activity/3695',
#             'https://affiliate.klook.com/jump/zh-TW/activity/1323-amazing-pass-osaka/?adid=9139&af_wid=1359': 'https://affiliate.klook.com/jump/zh-TW/activity/1323',
#             'https://affiliate.klook.com/jump/zh-TW/activity/1334-yokoso-osaka-ticket-osaka/?adid=12065&af_wid=1359': 'https://affiliate.klook.com/jump/zh-TW/activity/1334',
#             'https://affiliate.klook.com/jump/zh-TW/activity/599-/?adid=62284&af_wid=1359': 'https://affiliate.klook.com/jump/zh-TW/activity/599',
#             'https://affiliate.klook.com/jump/zh-TW/activity/1329-kansai-thru-pass-osaka/?adid=17766&af_wid=1359': 'https://affiliate.klook.com/jump/zh-TW/activity/1329',
#             'https://affiliate.klook.com/jump/zh-TW/activity/11515-/?adid=64033&af_wid=1359': 'https://affiliate.klook.com/jump/zh-TW/activity/11515',
#             'https://affiliate.klook.com/jump/zh-TW/activity/1754-/?adid=64032&af_wid=1359': 'https://affiliate.klook.com/jump/zh-TW/activity/1754',
#             'https://affiliate.klook.com/jump/zh-TW/activity/673-/?adid=23061&af_wid=1359': 'https://affiliate.klook.com/jump/zh-TW/activity/16216',
#             'https://affiliate.klook.com/jump/zh-HK/activity/22183-/?adid=61922&af_wid=1359': 'https://affiliate.klook.com/jump/zh-TW/activity/22183',
#             'https://affiliate.klook.com/jump/zh-TW/activity/3217-/?adid=40657&af_wid=1359': 'https://affiliate.klook.com/jump/zh-TW/activity/3217',
#             'https://affiliate.klook.com/jump/zh-TW/activity/598-osaka-aquarium-kaiyukan-japan/?adid=17767&af_wid=1359': 'https://affiliate.klook.com/jump/zh-TW/activity/598',
#             'https://affiliate.klook.com/jump/zh-TW/activity/2129-/?adid=31562&af_wid=2929': 'https://affiliate.klook.com/jump/zh-TW/activity/2129',
#             'https://affiliate.klook.com/jump/zh-TW/activity/2124-/?adid=31562&af_wid=2929': 'https://affiliate.klook.com/jump/zh-TW/activity/2124',
#             'https://affiliate.klook.com/jump/zh-TW/activity/3297-/?adid=31562&af_wid=2929': 'https://affiliate.klook.com/jump/zh-TW/activity/3297',
#             'https://affiliate.klook.com/jump/zh-TW/activity/7698-/?adid=31562&af_wid=2929': 'https://affiliate.klook.com/jump/zh-TW/activity/7698'
#         };
#
#         [].forEach.call(articleInner.querySelectorAll('a'), function (link) {
#             if (Object.keys(testLinks).indexOf(link.href) > -1) {
#                 var utmSource = getUrlParameter('utm_source');
#
#                 link.href = 'https://richart.tw/TSDIB_RichartWeb/RC07/RC070400?sn=' + testLinks[link.href] + '&tk=' +
#                 ((Object.keys(tkExtraParameters).indexOf(utmSource) > -1) ? tkExtraParameters[utmSource] : utmSource);
#             }
#
#                         if (Object.keys(mappingLinks).indexOf(link.href) > -1) {
#                 link.href = mappingLinks[link.href] + urlQuery + (isSourceFB ? 'fb' : getUrlParameter('utm_source'));
#             }
#         });
#     }
#
#     function getUrlParameter (name) {
#         var regex = new RegExp('[\\?&]' + name + '=([^&#]*)'),
#             results = regex.exec(window.location.search);
#         return results === null ? '' : decodeURIComponent(results[1].replace(/\+/g, ' '));
#     };
#
# })(jQuery);
# </script>
# <script src="//front.pixfs.net/js/pixhappix-ui-module--bundle.min.js?v=34e16fe28a09c688e00acd6028beefd8" defer></script>
# <script>
#     (function ($) {
#                 var articleInner = document.querySelectorAll('.article-content-inner')[0],
#             paragraphs = articleInner.querySelectorAll('p, hr, div'),
#             minInterval = 1500,
#             betweenAdInterval = 600,
#                         paragraphsNumber = paragraphs.length - 1,
#             index = Math.floor(paragraphsNumber / 2),
#             adPosition = paragraphs[index],
#             adGap = 0,
#             adIndexes = [],
#             hasAd = false,
#             betweenAdGap = 0,
#             octopusAdGap = minInterval / 2,
#             putOctopusAd = false;
#
#         for (var i = 0; i < paragraphsNumber; i++) {
#             var putAd = false;
#
#             if (paragraphs[i].parentNode !== articleInner) {
#                 continue;
#             }
#             adGap += paragraphs[i].clientHeight;
#
#                         if (hasAd) {
#                 betweenAdGap += paragraphs[i].clientHeight;
#                 if (betweenAdGap < betweenAdInterval) {
#                     continue;
#                 }
#                 hasAd = false;
#             }
#
#             if (hasAdInParagraph(paragraphs[i]) || hasAdInParagraph(paragraphs[i+1])) {
#                 hasAd = true;
#                 continue;
#             }
#
#                         if (paragraphs[i].innerText.trim().length === 0) {
#                 putAd = true;
#             }
#
#                         if (paragraphs[i].innerText.length < 30 && paragraphs[i].style.backgroundColor !== "") {
#                 putAd = true;
#             }
#
#                         if (hasImageInParagraph(paragraphs[i]) && hasImageInParagraph(paragraphs[i+1])) {
#                 putAd = true;
#             }
#
#                         if (!hasImageInParagraph(paragraphs[i]) && !hasImageInParagraph(paragraphs[i+1])) {
#                 putAd = true;
#             }
#
#                         if (adIndexes.length === 1 &&
#                 adGap >= octopusAdGap && adGap < minInterval &&
#                 !putOctopusAd &&
#                 putAd
#             ) {
#                 paragraphs[i].innerHTML += '<div class="article-inread-ad" id="in-read-rp"><ins class="adsbyfalcon" data-ad-client="1" data-ad-slot="3659"  style="display:inline-block;width:336px;height:280px;"></ins></div>';
#                 putOctopusAd = true;
#             }
#
#             if (adGap < minInterval) {
#                 continue;
#             }
#
#             if (putAd) {
#                 adIndexes.push(i);
#                 adGap = 0;
#             }
#         }
#
#         adIndexes.map(function (index, i) {
#             paragraphs[index].innerHTML += generateInReadAd(i + 1);
#         });
#
#                 if (paragraphsNumber === 0) {
#             $('.author-profile').before(generateInReadAd(1));
#             return;
#         }
#
#                 function generateInReadAd(index) {
#             index = Math.max(1, index);
#             var MIBClass = true ? ' mib-ad-box' : '';
#
#             return '<div class="article-inread-ad' + MIBClass + '" data-adindex="' + index + '">' +
#                 generateInReadAdPos(index - 1) + '</div>';
#         }
#
#                 function generateInReadAdPos(id) {
#             var ads = [
#                                     '<ins class="adsbyfalcon" data-ad-client="1" data-ad-slot="3132" data-embed="false" data-merge-position="3342" style="display:inline-block;width:336px;height:280px;"></ins>',
#                                     '<ins class="adsbyfalcon" data-ad-client="1" data-ad-slot="3133" data-embed="false" data-merge-position="3347" style="display:inline-block;width:336px;height:280px;"></ins>',
#                                     '<ins class="adsbyfalcon" data-ad-client="1" data-ad-slot="3134" data-embed="false" data-merge-position="3352" style="display:inline-block;width:336px;height:280px;"></ins>',
#                                     '<ins class="adsbyfalcon" data-ad-client="1" data-ad-slot="3135" data-embed="false" data-merge-position="3357" style="display:inline-block;width:336px;height:280px;"></ins>',
#                                 ],
#                 key = Math.min(Math.floor(id / 6), ads.length - 1);
#
#                 // 第一則為rich media廣告
#                 if (id === 0) {
#                     return '<ins class="adsbyfalcon" data-ad-client="1" data-ad-slot="3542" data-embed="false" data-merge-position="3342" style="display:inline-block;width:336px;height:280px;"></ins>';
#                 }
#
#                 return ads[key];
#         }
#
#                 function hasAdInParagraph(p) {
#             return p.innerHTML.toLowerCase().indexOf('<iframe') >= 0;
#         }
#
#                 function hasImageInParagraph(p) {
#             return p.innerHTML.toLowerCase().indexOf('<img') >= 0;
#         }
#     })(jQuery);
# </script>
#     </div> <!-- #article-box //-->
#           <div id="user-post">
#     <div id="comment-box" class="user-post-box">
#       <a name="comments"></a>
#       <h3 id="comment-title" class="user-post-title" onclick="pix.commentSwitch('comment-text','comment-text-switch');" style="cursor:hand;cursor:pointer;"><img id="comment-text-switch" src="//s.pixfs.net/blog/images/choc/minus.gif"> <span id="comment-title-span">留言列表</span></h3>
#       <div class="post-comment"><a href="/blog/post/46339070#comment-form">發表留言</a></div>
#       <div id="comment-text" class="user-post-text">
#       </div> <!-- #comment-text //-->
#       <div id='comment_form'>
#       </div>
#     </div> <!--  #comment-box //-->
#   </div> <!-- #user-post //-->
#         </div> <!-- #article-area //-->
#             </div> <!-- #content //-->
#             <div id="links">
#               <div id="sidebar__inner">
#                   <div id="links-row-1">
#                                             <div class="hslice box folder" id="box1096266">
#     <h4 class="box-title entry-title">
#             好朋友們推薦的文章    	    </h4>
#     <div class="box-text entry-content">
#
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <div class="fb-recommendations" data-site="http://butterfly927.pixnet.net/blog" data-width="220" data-height="350" data-header="true"></div>    </div>
# </div> <!-- #box1096266 //-->
# <div class="hslice box folder" id="box239742">
#     <h4 class="box-title entry-title">
#             用 mail 就可以訂閱文章喔^_^    	    </h4>
#     <div class="box-text entry-content">
#
# <form style="border:1px solid #fff;padding:3px;text-align:center;" action="http://feedburner.google.com/fb/a/mailverify" method="post" target="popupwindow" onsubmit="window.open('http://feedburner.google.com/fb/a/mailverify?uri=pixnet/FPvj', 'popupwindow', 'scrollbars=yes,width=550,height=520');return true"><p>請輸入Mail 帳號：</p><p>
#   <input type="text" style="width:140px" name="email" size="20"/></p><input type="hidden" value="pixnet/FPvj" name="uri"/><input type="hidden" name="loc" value="en_US"/><input type="submit" value="送 出" /><p style="margin-top: 10; margin-bottom: 0">要【驗證】後才能正式啟用喔</p>
#   <p style="margin-top: 0; margin-bottom: 0"><font face="Webdings">Y </font>蝶~
#   感恩您的鼓勵<font face="Webdings"> Y</font></p></form></p>
#     </div>
# </div> <!-- #box239742 //-->
# <div class="hslice box" id="search">
#     <h4 class="box-title entry-title">
#             文章搜尋    	    </h4>
#     <div class="box-text entry-content">
#
# <form method="post" action="https://butterfly927.pixnet.net/blog/search/" id="search-form" data-wording-needkeyword="請輸入關鍵字">
# 	<ul>
# 	    <li><input name="search-target" id="search-target" type="text" ></li>
# 	    <li><input id="search-submit" type="submit" value="搜尋" ></li>
# 	</ul>
#     </form>
#     <script type="text/javascript">//<!--
#     jQuery('#search-form').submit(function(event){
#         if ('' === jQuery('#search-target').val()) {
#             alert(jQuery(this).attr('data-wording-needkeyword'));
#             event.preventDefault();
#         }
#     });
#     //--></script>
#     </div>
# </div> <!-- #search //-->
# <div class="hslice box folder" id="box249900">
#     <h4 class="box-title entry-title">
#             歡迎您轉寄引用    	    </h4>
#     <div class="box-text entry-content">
#
# <p style="margin-top: 5; margin-bottom: 0" align="center">
# <img border="0" src="https://pic.pimg.tw/butterfly927/1517554391-3455926276_n.jpg" width="220"></p>
# 禪的真善美種子需要大家一起來灌溉<br>
# 如果您覺得蝶用心寫的文<br>
# 可以喚起人性那一絲絲的光明<br>
# 歡迎您轉寄或引用<br>
# 註明出處即可<br>
# <br>
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-24697198-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# ...
#                     </div>
#                 </div>
#
#             </div>
#
#             <div class="comment-body">
#
#                                     <p class="comment-area-title">您尚未登入，將以<b>訪客</b>身份留言。亦可以上方服務帳號登入留言</p>
#
#
#                                     <div class="comment-textarea">
#                         <input type="text" name="nickname" class="comment-name" placeholder="您的暱稱 ..." data-ng-model="nickname" required>
#                         <p data-ng-show="guestbookCommentForm.nickname.$error.required" class="private-notice">請輸入暱稱 ( 最多顯示 6 個中文字元 )</p>
#                     </div>
#
#                 <div class="comment-textarea">
#                     <input type="text" name="title" class="comment-name" placeholder="留言標題 ..." data-ng-model="title" required>
#                     <p data-ng-show="guestbookCommentForm.title.$error.required" class="private-notice">請輸入標題 ( 最多顯示 9 個中文字元 )</p>
#                 </div>
#                 <div class="comment-textarea">
#                     <textarea name="content" id="comment_text" placeholder="留個言吧 ..." data-ng-model="content" required></textarea>
#                     <p data-ng-show="guestbookCommentForm.content.$error.required" class="private-notice">請輸入內容 ( 最多 140 個中文字元 )</p>
#                 </div><!-- .comment-textarea -->
#
#
#                 <div id="comment-area-ad" style="display:block"></div>
#                 <div data-reload-captcha class="captcha" style="display:block" id="captcha">
#                     <a href="" target="_blank">
#                         <img class="reload-captcha-img" data-ng-src="//captcha.pixplug.in/image/1.1/7191387570d8dff6a4b864ed7f0fd0db/5a1f498e81923dcb0f34af48249d5c87/200x50.jpeg" width="200" height="50">
#                     </a>
#                     <div>
#                         <p>請輸入左方認證碼：</p>
#                         <input type="text" name="authCode" class="text-input" data-ng-model="authCode" required>
#                         <a class="reload-captcha-btn" href=""><p>看不懂,換張圖</p></a>
#                     </div>
#                     <p data-ng-show="guestbookCommentForm.authCode.$error.required" class="private-notice">請輸入驗證碼</p>
#                 </div>
#
#                 <div class="comment-extra">
#                     <button type="submit" data-ng-disabled="guestbookCommentForm.$invalid" class="btn-comment-send" href="">送出留言</button>
#                 </div>
#
#             </div><!--.comment-middle-->
#         </div><!-- #comment-area-2-->
#         <div ng-show="isLoading" class="spinner-wrap">
#             <div class="spinner" us-spinner="{ radius:20, lines: 11, width:10, length: 16, zIndex: 800, top: -300, left: 200, trail: 74 }"></div>
#         </div>
#     </div>
# </form>
# </div>
#
# <script src="//front.pixfs.net/js/guestbook-comment.min.js?v=34e16fe28a09c688e00acd6028beefd8"></script>
#
#
# <script>
#     pix.stylemeTags = [];
#     pix.isBlogArticle = true;
# </script>
# <script src="//front.pixfs.net/js/styleme.min.js?v=34e16fe28a09c688e00acd6028beefd8" crossorigin="anonymous"></script>
#
# <script>
# (function () {
#     pix.octopusTags = null;
#     if (null === pix.octopusTags || undefined === pix.octopusTags) {
#         return;
#     }
#     for (var i = 0; i < pix.octopusTags.length; i++) {
#         if ('' === pix.octopusTags[i]) {
#             continue;
#         }
#         _piq.push(['trackEvent', 'otopusTag', '', pix.octopusTags[i]]);
#     }
# })();
# </script>
#
#
# <script>
#   var nineyi_group    = "X1";
#   var nineyi_keyindex = "0";
#   var nineyi_match    = "";
#   var nineyi_id       = "pix91_4923eadf23f842f1d2ca782390fd00ad";
#   var nineyi_products = [{"asset":"0104","image":"\/\/pic.pimg.tw\/pixnetvisual\/1446126120-4162329176_s.jpg?v=1446126272","title":"MissHana\u82b1\u5a1c\u5c0f\u59d0\u5b8c\u7f8e\u7121\u75d5\u4e09\u8272\u906e\u7455\u818f","oprice":"380","nprice":"299","link":"\/\/www.86shops.com.tw\/SalePage\/Index\/1256490"},{"asset":"0138","image":"\/\/pic.pimg.tw\/pixnetvisual\/1446126147-4136062762_s.jpg?v=1446126272","title":"E\u2027Heart \u4f0a\u5fc3 \u6301\u4e45\u96b1\u5f62\u96d9\u9762\u96d9\u773c\u76ae\u8cbc","oprice":"348","nprice":"180","link":"\/\/www.86shops.com.tw\/SalePage\/Index\/344734"},{"asset":"0143","image":"\/\/pic.pimg.tw\/pixnetvisual\/1446126150-2749437497_s.jpg?v=1446126272","title":"3CE (3CONCEPT EYES) \u8d85\u986f\u8272\u5507\u818f","oprice":"499","nprice":"399","link":"\/\/www.86shops.com.tw\/SalePage\/Index\/1610019"},{"asset":"0223","image":"\/\/pic.pimg.tw\/pixnetvisual\/1446126232-3103690318_s.jpg?v=1446126273","title":"ND \u812b\u6bdb\u871c\u881f\/\u9664\u6bdb\u871c\u881f 220g","oprice":"299","nprice":"299","link":"\/\/www.86shops.com.tw\/SalePage\/Index\/1035850"},{"asset":"0160","image":"\/\/pic.pimg.tw\/pixnetvisual\/1446126167-2508883353_s.jpg?v=1446126272","title":"\u97d3\u570b RiRe \u9ed1\u982d\u7c89\u523a\u6e05\u6f54\u5237 \u4e59\u652f\u5165(\u5167\u9644\u6e05\u6f54\u4e7320mL)","oprice":"290","nprice":"290","link":"\/\/www.86shops.com.tw\/SalePage\/Index\/640966"},{"asset":"0109","image":"\/\/pic.pimg.tw\/pixnetvisual\/1446126124-168867797_s.jpg?v=1446126272","title":"Miss Hana \u82b1\u5a1c\u5c0f\u59d0 \u6c34\u611f\u63a7\u8272CC\u971c","oprice":"349","nprice":"299","link":"\/\/www.86shops.com.tw\/SalePage\/Index\/668815"}];
# </script>
# <script id="idleTemplate" type="text/x-jsrender" data-main="//front.pixfs.net/module/idlePop/js/idlePop.min.js?v=34e16fe28a09c688e00acd6028beefd8">
# <link rel="stylesheet" href="//front.pixfs.net/module/idlePop/css/idlePop.min.css?v=34e16fe28a09c688e00acd6028beefd8">
# <div class="modal idle-pop" tabindex="-1" role="dialog" aria-describedby="dialog">
#   <div class="modal-bg"></div>
#   <div class="modal-dialog">
#     <a class="modal-close" data-close="【 關閉 X 】"></a>
#
#     <div class="modal-content">
#       <div class="modal-header">本網頁已閒置超過 3 分鐘。請點 <kbd>關閉</kbd> 或 <kbd>點擊</kbd>任一空白處，即可回到網頁</div>
#       <div class="modal-body">
#         <div class="blogger-info">
#             <a class="blogger-info__avatar" href="http://www.pixnet.net/pcard/butterfly927?utm_source=PIXNET&utm_medium=post_pause&utm_term=&utm_content=46339070"><img src="{{:user.avatar}}" alt="{{:user.name}} 的大頭貼"></a>
#
#           <div class="blogger-info__profile">
#             <div class="blogger-info__row">
#               <dl>
#                 <dt>部落格名稱</dt>
#                 <dd><a href="{{:blog.link}}">{{:blog.name}}</a></dd>
#               </dl>
#             </div>
#
#             <div class="blogger-info__row">
#               <dl>
#                 <dt>人氣</dt>
#                 <dd data-unit="人">{{:blog.hits.total}}</dd>
#
#                 <dt>好友數</dt>
#                 <dd data-unit="人">{{:user.friends_count}}</dd>
#
#                 <dt>文章總數</dt>
#                 <dd data-unit="篇">{{:blog.articles_count}}</dd>
#               </dl>
#             </div>
#
#             <div class="blogger-info__row hoverable">
#
#         <a class="subscribe-btn" href="https://classic-panel.pixnet.cc/login/openid?done=http%3A%2F%2Fbutterfly927.pixnet.net%2Fblog%2Fpost%2F46339070%3Futm_source%3DPIXNET%26utm_medium%3DBlog_follow&openid=https%3A%2F%2Fmember.pixnet.cc%2Flogin&easy_login=1" data-follow-state="關注"></a>
#             </div>
#
#           </div>
#         </div>
#
#         <div class="idle-adsense">
#         </div>
#
#         <div class="idle-related-posts">
#           {{for posts}}
#           <a class="idle-related-post" href="{{:link}}">
#             <img src="{{:thumb}}" alt="文章縮圖">
#             <div class="idle-related-post__detail">
#               <h4>{{:title}}</h4>
#               <div class="idle-related-post__desc" data-readmore="繼續閱讀">{{:body}}</div>
#             </div>
#           </a>
#           {{/for}}
#         </div>
#       </div>
#       <div class="modal-footer"></div>
#     </div>
#   </div>
# </div>
# </script>
#
# <script id="idleTemplateBig" type="text/x-jsrender" data-main="//front.pixfs.net/module/idlePop/js/idlePop.min.js?v=34e16fe28a09c688e00acd6028beefd8">
# <link rel="stylesheet" href="//front.pixfs.net/module/idlePop/css/idlePop.min.css?v=34e16fe28a09c688e00acd6028beefd8">
# <div class="modal idle-pop idle-pop__big" tabindex="-1" role="dialog" aria-describedby="dialog">
#   <div class="modal-bg"></div>
#   <div class="modal-dialog">
#     <a class="modal-close" data-close="【 關閉 X 】"></a>
#
#     <div class="modal-content">
#       <div class="modal-header">本網頁已閒置超過 3 分鐘。請點 <kbd>關閉</kbd> 或 <kbd>點擊</kbd>任一空白處，即可回到網頁</div>
#       <div class="modal-body">
#         <div class="modal-top">
#           <div class="modal-top__left">
#             <div class="blogger-info">
#                 <a class="blogger-info__avatar" href="http://www.pixnet.net/pcard/butterfly927?utm_source=PIXNET&utm_medium=post_pause&utm_term=&utm_content=46339070"><img src="{{:user.avatar}}" alt="{{:user.name}} 的大頭貼"></a>
#
#               <div class="blogger-info__profile">
#                 <div class="blogger-info__row">
#                   <dl>
#                     <dt>部落格名稱</dt>
#                     <dd><a href="{{:blog.link}}">{{:blog.name}}</a></dd>
#                   </dl>
#                 </div>
#
#                 <div class="blogger-info__row">
#                   <dl>
#                     <dt>人氣</dt>
#                     <dd data-unit="人">{{:blog.hits.total}}</dd>
#
#                     <dt>好友數</dt>
#                     <dd data-unit="人">{{:user.friends_count}}</dd>
#
#                     <dt>文章總數</dt>
#                     <dd data-unit="篇">{{:blog.articles_count}}</dd>
#                   </dl>
#                 </div>
#
#                 <div class="blogger-info__row hoverable">
#
#         <a class="subscribe-btn" href="https://classic-panel.pixnet.cc/login/openid?done=http%3A%2F%2Fbutterfly927.pixnet.net%2Fblog%2Fpost%2F46339070%3Futm_source%3DPIXNET%26utm_medium%3DBlog_follow&openid=https%3A%2F%2Fmember.pixnet.cc%2Flogin&easy_login=1" data-follow-state="關注"></a>
#                 </div>
#               </div>
#             </div>
#             <div class="idle-related-posts">
#               {{for posts}}
#               <a class="idle-related-post" href="{{:link}}">
#                 <div class="idle-related-post__detail">
#                   <h4>{{:title}}</h4>
#                   <div class="idle-related-post__desc" data-readmore="繼續閱讀">{{:body}}</div>
#                 </div>
#               </a>
#               {{/for}}
#             </div>
#           </div>
#           <div class="modal-top__right">
#             <div class="idle-adsense">
#             </div>
#           </div>
#         </div>
#       </div>
#       <div class="modal-footer"></div>
#     </div>
#   </div>
# </div>
# </script>
#
# <script src="//front.pixfs.net/js/hide-ad-checker.min.js?v=34e16fe28a09c688e00acd6028beefd8" crossorigin="anonymous"></script>
#
#
# <script>
#     document.addEventListener('DOMContentLoaded', function () {
#             var moveHouse = document.querySelector('.move-screen');
#             if (moveHouse) {
#                 _piq.push(['trackEvent', 'moveHouse', 'DOMContentLoaded', 'desktop']);
#             }
#     });
# </script>
# <script>
# _oq = window._oq || [];
# _oq.push(
#     ['categoryId', document.body.dataset.articleSiteCategoryId],
#     ['octopusTags', pix.octopusTags || []],
#     ['articleTitle', document.querySelector('.title > h2 > a').innerText],
#     ['octopusDom', document.getElementsByClassName('octopus')]
# );
# </script>
# <script>
# (function () {
#     window.requestAnimFrame = (function () {
#         'use strict';
#         return  window.requestAnimationFrame       ||
#                 window.webkitRequestAnimationFrame ||
#                 window.mozRequestAnimationFrame    ||
#                 window.oRequestAnimationFrame      ||
#                 window.msRequestAnimationFrame     ||
#                 function (callback) {
#                     window.setTimeout(callback, 1000 / 60);
#                 };
#     })();
#
#     // handle multiple browsers for cancelAnimationFrame() ref:https://msdn.microsoft.com/zh-tw/library/hh920765(v=vs.85).aspx
#     window.cancelAnimFrame = (function () {
#         return window.cancelAnimationFrame ||
#             window.webkitCancelAnimationFrame ||
#             window.mozCancelAnimationFrame ||
#             window.oCancelAnimationFrame ||
#             function (id) {
#                 window.clearTimeout(id);
#             };
#     })();
#
#     pix.octopusTags = null;
#     if (null === pix.octopusTags || undefined === pix.octopusTags) {
#         return;
#     }
#     for (var i = 0; i < pix.octopusTags.length; i++) {
#         if ('' === pix.octopusTags[i]) {
#             continue;
#         }
#         _piq.push(['trackEvent', 'otopusTag', '', pix.octopusTags[i]]);
#     }
# })();
# </script>
#
# <script>
# (() => {
#     const getUrlQuery = (query) => {
#         const url = new URL(location.href);
#         const params = url.searchParams;
#         for (let pair of params.entries()) {
#             if (pair[0] === query) {
#                 return pair[1];
#             }
#         }
#         return '';
#     };
#     const imgAnchorSrc = decodeURIComponent(getUrlQuery('img_anchor'));
#
#     if (!imgAnchorSrc) {
#         return;
#     }
#
#     const anchorImg = Array.from(document.getElementsByTagName('img'))
#         .filter((img) => img.src === imgAnchorSrc || img.dataset.original === imgAnchorSrc)[0];
#
#     if (!anchorImg) {
#         return;
#     }
#
#     const mainElement = document.getElementById('container');
#     mainElement.style.filter = 'blur(2px)';
#
#     const loadingElement = document.createElement('div');
#     loadingElement.style.position = 'fixed';
#     loadingElement.style.top = '0';
#     loadingElement.style.left = '0';
#     loadingElement.style.zIndex = '3';
#     loadingElement.style.display = 'flex';
#     loadingElement.style.justifyContent = 'center';
#     loadingElement.style.alignItems = 'center';
#     loadingElement.style.width = '100%';
#     loadingElement.style.height = '100%';
#     loadingElement.style.color = '#fff';
#     loadingElement.style.fontSize = '25px';
#     loadingElement.style.backgroundColor = 'rgba(0, 0, 0, .6)';
#     loadingElement.textContent = 'Searching Image...';
#     document.body.appendChild(loadingElement);
#
#     let timer = null;
#
#     const updateState = () => {
#         const imgTop = anchorImg.offsetTop;
#
#         if (Math.abs(window.scrollY - imgTop) / imgTop <= .03) {
#             clearInterval(timer);
#             mainElement.style.filter = '';
#             document.body.removeChild(loadingElement);
#         }
#
#         window.scrollTo({
#             top: imgTop - 80,
#             left: 0,
#             behavior: 'smooth'
#         });
#     };
#
#     timer = setInterval(updateState, 250);
#
#     window._piq = window._piq || [];
#     window._piq.push(['trackEvent', 'page view', 'line bot', location.href]);
# })();
# </script>
#
# <script defer src="//front.pixfs.net/js/side-effect.min.js?v=34e16fe28a09c688e00acd6028beefd8" type="text/javascript" crossorigin="anonymous"></script>
# <script defer src="//front.pixfs.net/module/fullPage/dist/ad-full-page.min.js?v=34e16fe28a09c688e00acd6028beefd8" type="text/javascript" crossorigin="anonymous"></script>
# <script src="https://front.pixfs.net/js/sticky-sidebar-ad.min.js?v=34e16fe28a09c688e00acd6028beefd8"></script>
# <script src="https://falcon-asset.pixfs.net/js/clickLinkFormat.min.js?v=34e16fe28a09c688e00acd6028beefd8"></script>
# <script src="https://falcon-asset.pixfs.net/js/adVideo.min.js?v=34e16fe28a09c688e00acd6028beefd8"></script>
#
# <script src="https://octopus-asset.pixfs.net/js/octopus_modern.min.js?v=34e16fe28a09c688e00acd6028beefd8" type="module" crossorigin="anonymous" defer></script>
# <script nomodule src="https://octopus-asset.pixfs.net/js/octopus_legacy.min.js?v=34e16fe28a09c688e00acd6028beefd8" crossorigin="anonymous" defer></script>
# <script defer src="https://libs.pixfs.net/axios/v0.18.0/axios.min.js"></script>
# <script type="module" src="https://front.pixfs.net/js/article-comments--bundle.min.js?v=34e16fe28a09c688e00acd6028beefd8"></script>
# <script nomodule src="https://front.pixfs.net/js/article-comments--bundle.min.js?v=34e16fe28a09c688e00acd6028beefd8"></script>
# <ins class="adsbyfalcon" data-ad-client="1" data-ad-slot="3731" data-embed="false" style="display:inline-block;"></ins></body>
# </html>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text,'lxml')
print(soup.select('.article-content-inner p'))
# Out:
# [<p>1、放下壓力，累與不累，取決於自己的心態</p>, <p>心靈的房間，不打掃就會落滿灰塵。蒙塵的心，會變得灰色和迷茫。我們每天都要經歷很多事情，開心的，不開心的，都在心裡安家落戶。心裡的事情一多，就會變得雜亂無序，然後心也跟著亂起來。有些痛苦的情緒和不愉快的記憶，如果充斥在心裡，就會使人委靡不振。所以，掃地除塵，能夠使黯然的心變得亮堂；把事情理清楚，才能告別煩亂；把一些無謂的痛苦扔掉，快樂就有了更多更大的空間。</p>, <p>緊緊抓住不快樂的理由，無視快樂的理由，就是你總是覺得難受的原因了。<!-- more --></p>, <p> </p>, <p>2、放下煩惱，快樂其實很簡單</p>, <p>所謂練習微笑，不是機械地挪動你的面部表情，而是努力地改